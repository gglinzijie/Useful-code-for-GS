# %%
x <- seq(-5, 5, length=1000)
y <- dnorm(x, mean=0, sd=1)
plot(x, y, type="l", lwd=1,col="red")
# Out:
# plot without title

# %%
x1<-rnorm(1000,mean=0, sd=2)
x2<-rep(0,1000)
xall<-rbind(x1,x2)
hist(xall,breaks=150,xlim=c(-10,10),freq=FALSE)
# Out:
# Plot with title "Histogram of xall"

# %%
x <- seq(-5, 5, length=1000)
y <- dnorm(x, mean=0, sd=1)
plot(x, y, type="l", lwd=1,col="red",xlim = c(-6,6),ylim = c(0,0.5))
par(new=TRUE)
ｍ<-dlaplace(x)
plot(x, ｍ, type="l", lwd=1,col = "black",xlim = c(-6,6),ylim = c(0,0.5))
# Out:
# plot without title

# %%
library("LaplacesDemon")
library("ggplot2")
x <- seq(-5, 5, length=1000)
y<-dlaplace(x)
data<-data.frame(x,y)
ggplot(data, aes(x=x, y=y))+
geom_point(color="red")+
theme(axis.text=element_text(size=40,face="bold"),
        axis.title=element_text(size=20,face="bold"),
     axis.title.x=element_blank(),
     axis.title.y=element_blank())
# Out:
# plot without title
